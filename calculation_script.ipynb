# %%
import json
import xlsxwriter
my_list = [];

names = []

flop_byte = []
flop_time = []

for name in names:
 
    with open(name) as f:
        lines = f.readlines() # list containing lines of file
        columns = [] # To store column names

        i = 1
        ffma = 0
        fadd = 0
        fmul = 0
        memory = 0
        time = 0
        for line in lines:
            words = line.split()
            for i in range(len(words)):
                if(words[i] == "smsp__sass_thread_inst_executed_op_ffma_pred_on.sum"):
                    ffma = ffma + float(words[i+2])
                if(words[i] == "smsp__sass_thread_inst_executed_op_fadd_pred_on.sum"):
                    fadd = fadd + float(words[i+2])
                if(words[i] == "smsp__sass_thread_inst_executed_op_fmul_pred_on.sum"):
                    fmul = fmul + float(words[i+2])
                if(words[i] == "Gbyte"):
                    memory = memory + float(words[i+1])*pow(10,9)
                if(words[i] == "Mbyte"):
                    memory = memory + float(words[i+1])*pow(10,6)
                if(words[i] == "Kbyte"):
                    memory = memory + float(words[i+1])*pow(10,3)
                try:
                    if(words[i] == "usecond"):
                        time = time + float(words[i+1])/1000000
                except:
                    print("error")
                if(words[i] == "msecond"):
                    time = time + float(words[i+1])/1000
    
        flops = fadd + fmul + 2*ffma
        print(name)
        print("  flops : " , flops)
        print("  memory : " , memory)
        print("  time : " , time)
        print("  flop/byte : " , (flops/memory))
        print("  flop/sec : " , (flops/time)/pow(10,12))
# Out:
# ayush/ncu-alexnet-a100-new.txt
#   flops :  34084737052.0
#   memory :  6992987680.0
#   time :  0.01173464
#   flop/byte :  4.874130859615643
#   flop/sec :  2.904625710886742
# ayush/ncu-resnet18-a100-new.txt
#   flops :  23208258844.0
#   memory :  16545950360.0
#   time :  0.03153442999999999
#   flop/byte :  1.4026549300006481
#   flop/sec :  0.7359656998398262
# ayush/ncu-vgg11-a100-new.txt
#   flops :  79187493084.0
#   memory :  47370871150.0
#   time :  0.07417457999999998
#   flop/byte :  1.671649500243569
#   flop/sec :  1.0675826284961778
# v100/ncu-alexnet-v100-new.txt
#   flops :  105934449692.0
#   memory :  9557037770.0
#   time :  0.019506280000000004
#   flop/byte :  11.08444397117832
#   flop/sec :  5.43078688976063
# error
# v100/ncu-resnet18-v100-new.txt
#   flops :  337050821212.0
#   memory :  24062410380.0
#   time :  0.05807364999999993
#   flop/byte :  14.007359025517543
#   flop/sec :  5.803851165063681
# v100/ncu-vgg11-v100-new.txt
#   flops :  881662738652.0
#   memory :  76545195860.0
#   time :  0.15031947999999987
#   flop/byte :  11.518198219318005
#   flop/sec :  5.865259370588567
